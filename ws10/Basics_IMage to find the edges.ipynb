# %%
from scipy import misc

# %%
img=misc.ascent()

# %%
img
# Out:
# array([[ 83,  83,  83, ..., 117, 117, 117],
#        [ 82,  82,  83, ..., 117, 117, 117],
#        [ 80,  81,  83, ..., 117, 117, 117],
#        ...,
#        [178, 178, 178, ...,  57,  59,  57],
#        [178, 178, 178, ...,  56,  57,  57],
#        [178, 178, 178, ...,  57,  57,  58]])

# %%
img.shape
# Out:
# (512, 512)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
import numpy

# %%
f=numpy.array([[1,21,1],[0,0,0],[-1,-2,-1]])

# %%
f.shape
# Out:
# (3, 3)

# %%
#COnvolve 
img
# Out:
# array([[ 83,  83,  83, ..., 117, 117, 117],
#        [ 82,  82,  83, ..., 117, 117, 117],
#        [ 80,  81,  83, ..., 117, 117, 117],
#        ...,
#        [178, 178, 178, ...,  57,  59,  57],
#        [178, 178, 178, ...,  56,  57,  57],
#        [178, 178, 178, ...,  57,  57,  58]])

# %%
from scipy import misc

# %%
from scipy.signal import convolve2d

# %%
con_img=convolve2d(img,f)

# %%
con_img
# Out:
# array([[  83, 1826, 1909, ..., 2691, 2574,  117],
#        [  82, 1804, 1887, ..., 2691, 2574,  117],
#        [  -3, 1512, 1532, ..., 2223, 2223,    0],
#        ...,
#        [   0, 3382, 3382, ..., 1080, 1102,    1],
#        [-178, -534, -712, ..., -227, -171,  -57],
#        [-178, -534, -712, ..., -229, -173,  -58]])

# %%
plt.imshow(con_img, cmap="gray")
